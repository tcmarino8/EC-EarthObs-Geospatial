# %%
#!/usr/bin/env python

# make sure to install these packages before running:
#pip install pandas
# pip install sodapy

import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.sfgov.org", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.sfgov.org,
#                  MyAppToken,
#                  username="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("ab4h-6ztd", limit=2000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)

# %%
# !pip install matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
dontParkSF = results_df

# %%
dontParkSF['fine_amount'] = [float(x) for x in dontParkSF['fine_amount']]

# %%
dontParkSF[dontParkSF['fine_amount'] >= 100].head(5)
# Out:
#    citation_number citation_issued_datetime   violation violation_desc  \
# 41       842288845  2014-06-07T14:19:00.000     V22500F     ON SIDEWLK
# 42      1003702114  2016-04-25T13:10:00.000  TRC7.2.44A      ON ST LST
# 43      1006337861  2022-04-03T14:00:00.000   TRC7.2.42     RESTRICTED
# 51       770187143  2009-09-01T23:41:00.000     V22500F     ON SIDEWLK
# 82      PD20182573  2009-10-27T05:10:00.000      V5200A        PLT F/R
#
#    citation_location vehicle_plate_state vehicle_plate  fine_amount  \
# 41   408 SOMERSET ST                  CA       4FJY956        110.0
# 42        617 2ND ST                  CA       5ARU718        875.0
# 43  1000 TURK STREET                  CA       8JYA770        108.0
# 51      3347 21ST ST                  GA       AYY8672        103.0
# 82   2135 BRYANT ST.                  CA       5NKK298        103.0
#
#                  date_added  \
# 41  2018-08-06T00:00:00.000
# 42  2020-09-15T00:00:00.000
# 43  2022-04-30T00:00:00.000
# 51  2009-09-01T00:00:00.000
# 82  2009-10-27T00:00:00.000
#
#                                              the_geom  \
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 51  {'type': 'Point', 'coordinates': [-122.4221780...
# 82                                                NaN
#
#    :@computed_region_jwn9_ihcz :@computed_region_6qbp_sg9q  \
# 41                         NaN                         NaN
# 42                         NaN                         NaN
# 43                         NaN                         NaN
# 51                          52                          52
# 82                         NaN                         NaN
#
#    :@computed_region_qgnn_b9vv :@computed_region_26cr_cadq  \
# 41                         NaN                         NaN
# 42                         NaN                         NaN
# 43                         NaN                         NaN
# 51                           3                           5
# 82                         NaN                         NaN
#
#    :@computed_region_ajp5_b2md
# 41                         NaN
# 42                         NaN
# 43                         NaN
# 51                          20
# 82                         NaN

# %%
dontParkSF.groupby('violation').sum('fine_amount').head(3)
# Out:
#            fine_amount
# violation
# GO1.H.2           50.0
# GO1.H.3           30.0
# NO VIOL            0.0

# %%
dontParkSF.groupby('vehicle_plate').sum('fine_amount'
).sort_values('fine_amount', ascending= False).head(5)
# Out:
#                fine_amount
# vehicle_plate
# 5ARU718              875.0
# 6APR817              303.0
# GYZ432               303.0
# 5BDA370              253.0
# 5ZIM710              253.0

# %%
dontParkSF.groupby('vehicle_plate').count(
).sort_values('fine_amount', ascending= False).head(4)
# Out:
#                citation_number  citation_issued_datetime  violation  \
# vehicle_plate
# 5B75822                      3                         3          3
# 4ZYC232                      2                         2          2
# 5SJF457                      2                         2          2
# 3NIN864                      2                         2          2
#
#                violation_desc  citation_location  vehicle_plate_state  \
# vehicle_plate
# 5B75822                     3                  3                    3
# 4ZYC232                     2                  2                    2
# 5SJF457                     2                  2                    2
# 3NIN864                     2                  2                    2
#
#                fine_amount  date_added  the_geom  :@computed_region_jwn9_ihcz  \
# vehicle_plate
# 5B75822                  3           3         3                            3
# 4ZYC232                  2           2         2                            2
# 5SJF457                  2           2         0                            0
# 3NIN864                  2           2         2                            2
#
#                :@computed_region_6qbp_sg9q  :@computed_region_qgnn_b9vv  \
# vehicle_plate
# 5B75822                                  3                            3
# 4ZYC232                                  2                            2
# 5SJF457                                  0                            0
# 3NIN864                                  2                            2
#
#                :@computed_region_26cr_cadq  :@computed_region_ajp5_b2md
# vehicle_plate
# 5B75822                                  3                            3
# 4ZYC232                                  2                            2
# 5SJF457                                  0                            0
# 3NIN864                                  2                            2

# %%
dontParkSF[dontParkSF['vehicle_plate'] == '5B75822']
# Out:
#     citation_number citation_issued_datetime violation violation_desc  \
# 110       773054041  2009-10-29T10:25:00.000   V22500F     ON SIDEWLK
# 244       770516202  2009-09-01T11:46:00.000    T202.1     PRK MTR #1
# 265       770924265  2009-09-11T11:45:00.000    T32A.1     TWAWY ZN#1
#
#         citation_location vehicle_plate_state vehicle_plate  fine_amount  \
# 110         685 MARKET ST                  CA       5B75822        103.0
# 244  27 NEW MONTGOMERY ST                  CA       5B75822         63.0
# 265            98 01ST ST                  CA       5B75822         73.0
#
#                   date_added  \
# 110  2009-10-29T00:00:00.000
# 244  2009-09-01T00:00:00.000
# 265  2009-09-11T00:00:00.000
#
#                                               the_geom  \
# 110  {'type': 'Point', 'coordinates': [-122.4025210...
# 244  {'type': 'Point', 'coordinates': [-122.4016062...
# 265  {'type': 'Point', 'coordinates': [-122.4196399...
#
#     :@computed_region_jwn9_ihcz :@computed_region_6qbp_sg9q  \
# 110                          32                          32
# 244                         108                         108
# 265                          21                          21
#
#     :@computed_region_qgnn_b9vv :@computed_region_26cr_cadq  \
# 110                           6                          10
# 244                           6                          10
# 265                           4                          10
#
#     :@computed_region_ajp5_b2md
# 110                           8
# 244                           8
# 265                          36

# %%
### Ok so we gotta figure out how to get each ticket a coordinate!
coordinates = []
for i in range(len(dontParkSF)):
    if dontParkSF['the_geom'][i].get('coordinates').isna():
        coordinates.append([0,0])
    coordinates.append(dontParkSF['the_geom'][i].get('coordinates'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[58], line 3
#       1 coordinates = []
#       2 for i in range(len(dontParkSF)):
# ----> 3     if dontParkSF['the_geom'][i].get('coordinates').isna():
#       4         coordinates.append([0,0])
#       5     coordinates.append(dontParkSF['the_geom'][i].get('coordinates'))
#
# AttributeError: 'list' object has no attribute 'isna'
